# %% [markdown]
# <h1 style="color:white;background-color:rgb(255, 108, 0);padding-top:1em;padding-bottom:0.7em;padding-left:1em;">1.1 Introduction to Jupyter Notebook and Python</h1>
# <hr>
#
# <h2>Introduction</h2>
#
# In this this lesson the usage of such notebooks as this will be introduced first.
# <br>
# After that, we will see how to perform basic operations with the Python programming language.

# %% [markdown]
# <h2>Jupyter Notebook and Google Colab</h2>
#
# The document you are currently reading is called a notebook and this environment that lets us to read and edit it is a
# <br>
# Jupyter Notebook environment.
#
# The content of these notebooks are organized into celss.
# <br>
# There are two types of cells, markdown and code. This cell is a markdown cell.
# <br>
# Markdown cell can be used to provide text and other form of explanation (figures, equations, links etc.)
# <br>
# The code cells can containg program code that can be executed inside the notebook. This brings an interactive
# <br>
# environment in which the theoretical explanations and the practical application can be done together.
# <br>
# In this course we eill be using Python as the programming language.
#
# Let's see how a code cell looks like! The cell below is a code cell that computes the result of the addition $2+3$.
# <br>
# Clik into the cell and press Ctrl+Enter or click on the Play button in the top left corner of the cell to
# <br>
# execute the code inside. You can also edit the code to compute something else.

# %%
2+3

# %% [markdown]
# You can see, that as you run the code, the output appears in the notebook.
# <br>
# You can also add new cells by pointing the bottom of the existing cells and clicing on the
# <br>
# ```+ CODE``` or the ```+ TEXT``` buttons or by pressing Shift + Enter at the end of the notebook. (This will also execute cell content.)
#
# Add a code cell after this markdown cell and compute the result of $2019*12$

# %% [markdown]
# <p style="margin-top:2em;">Google Colab is a Jupyter Notebook environment in the Cloud.</p>
# <br>
# Anyone with a google account can freely access it. When running a Jupyter Notebook in Colab,
# <br>
# the user is given a Virtual machine hosted in the Google cloud.
# <br>
# Most of the necessary application for our course are installed on this machine by default.
#
# For more info on Jupyter Notebook wisit https://jupyter.org/
# <br>
# Colab also provides several guides and tutorials accessible from its welcome page https://colab.research.google.com/notebooks/welcome.ipynb

# %% [markdown]
# <h2>Python</h2>
#
# Python is an interpreted object oriented programming language. Since there is no need for compilation
# <br>
# developing code in Python is very fast. It is also very convenient to use due to its object oriented
# <br>
# nature and clear, well readable syntax.
#
# These properties make Python good for rapid prototyping. It is also a very popular programming language
# <br>
# for comuter science applications thanks to its extensive set of modules and widespread support.
#
# During this course we will be using the Python programming language.
# <br>
# For more info on Python see https://www.python.org/
#
# <h3> Variables, Data types and Operations </h3>
#
# Just like in other programming languages the intermediate results and values in a Python program can be stored in variables.
# <br>
# Variables have a name, a value and a data type. In python the type of the varible is decided by the value assigned to it,
# <br>
# so there is no need to specify the type of the variable at its declaration.
#
# The basic data types are integer, float, string and boolean.
# <br>
# The integer type is for numeric data vithout fractional part like $1,\space -11,$ or $987$.
# <br>
# The float data type if for numeric data with fracional part such as $0.2,\space 2.4,\space -23.2222222$.
# <br>
# Strings are character series and in Python they can be written with either single or doule quotes eg.:
# ```python
# 'This is a single quote string'
# "This is a double quote string"
# ```
# If a sting is too long to fit in a single row, three single quotes can be used:
# ```python
# '''This is a string
# that contains multiple lines
# '''
# ```
# The boolean data type is for storing logical variables. These can only be either ```True``` or ```False```.
#
# A line in Python code followed by a hash mark is interpreted as comment and will not be executed.
#
# <p style="margin-top:2em;">Now let's see how to create different types of Python variables:</p>

# %%
#This is a comment that will not be executed

#Create an integer variable with a name 'a' and a value of 2
a = 2 #Comments can follow code as well, only the part after the hash mark will be ignored by the interpreter

#Float variable
b = 3.4

#String variable
c = 'This is a string'

#Boolean variable
d = True

#A variable can be repurposed at any time
a = False
b = c

# %% [markdown]
# <p style="margin-top:2em;">Python provides some useful built-in function that are helpful
# <br>
# for understanding the basics.</p>
#
# These are:
#  - ```print()``` This function prints its argument to the standard output
#  - ```type()``` This built-in function returns the data type of its argument
#  - ```help()``` This function can be used to display useful information on something
#
# Let's see how they work:

# %%
#Integer variable 'a' with a value of 2
a = 2

#Print the value of a
print('The value of a is:', a) #Here the print function is given 2 argument a string literal and the variable a

#Print the data type of a
print('The data type of a is:', type(a))

#Display help for the print function
help(print)

b = 2.3
c = 'String'
d = False

print('The data type of b is:', type(b))
print('The data type of c is:', type(c))
print('The data type of d is:', type(d))

# %% [markdown]
# Operators in Python are special symbols that perform some kind of computation.
# <br>
# An operation is made up of an operator and its operands. For example $2+3$ is an operation
# <br>
# where the + symbol is the operator and the numbers $2$ and $3$ are the operands.
# <br>
# This operation tells the interpreter to compute take the value of the operands and compute their sum.
#
# Operators can be binary or unary. A binary operator needs two operands, wile a unary operator needs only one.
# <br>
# The summation is a good example of a binary oerator. Negation is a unary operator.
#
# There are several operators in Python but for now we will only cover the most basic ones.
#
# Arithmetic opeartors:
#  - (binary) + , adds two numeric values (2+3)
#  - (unary) - , negates a numeric value (-2)
#  - (binary) - , subtracts operand2 from operand1 (3-2)
#  - (binary) * , multypies two values (2*3)
#  - (binary) / , divides operand1 by operand2 (4/2) (This operation returns a float value always!)
#  - (binary) % , remainder after the division (5%2) (Equals 1)
#  - (binary) // , floor division (9//4) (Equals 2)
#  - (binary) \** , exponent (3\**2) (Equals 9)
#
# Logical operations:
#  - (binary) and , logical and (True and False) (Results ```False```)
#  - (binary) or , logical or (True or False) (Results ```True```)
#  - (unary) not , logical negation (not True) (Results ```False```)
#
# Comparison opeartors (the result of comparison operations are boolean values):
#  - (binary) < , smaller than (2<3) (Results ```True```)
#  - (unary) > , greater than (2>3) (Results ```False```)
#  - (binary) == , equlaity (3==3) (Results ```True```)
#  - (binary) != , not equal (2!=3) (Results ```True```)
#  - (binary) >= , greater than or equal to (4>=2) (Results ```True```) (Equivalent to 4>2 or 4==2)
#  - (binary) <= , smaller than or equal to (4<=2) (Results ```False```) (Equivalent to 4<2 or 4==2)
#
# Assignment:
#  - (binary) = , sets the value of a variable (a=5)
#
# The assignment operators can be combined with the binary arithmetic operators like: ```+= , -= , *= , /= , %= , //= ```
# <br>
# The meaning of these can be best shown with exmples:
# <br>
# ```a += 1``` is equivalent to ```a = a+1```. Likewise ```a *= 2``` is equivalent to ```a = a*2```.
#
# Let's see examples of the usage of operators:

# %%
#Create variables
a = 2
b = 1.3
c = 5
d = True
s = 'This is a string'
s2 = 'This is an other string'

#Arithmetic operators:
print('a+b is :', a+b)
print('a-b is :', a-b)
print('-a is :', -a)
print('s+s2 is :', s+s2, ', and the data type is', type(s+s2))
print('a*b is :', a*b)
print('c/a is :', c/a, ', and the data type is', type(c/a))
print('c%a is :', c%a)
print('c//a is :', c//a)
print('c**a is :', c**a)

#Logical and comparison operators:
print('a<b is :', a<b)
print('a>c is :', a>c)
print('a==a is :', a==a)
print('s!=s2 is :', s!=s2)
print('a>=c is :', a>=c, 'and that it is equivalent to a>c or a==c is', (a>=c)==(a>c or a==c))
print('a<=c is :', a<=c, 'and that it is equivalent to a<c or a==c is', (a<=c)==(a<c or a==c))
print('d and False is :', d and False)
print('d and True is :', d and True)

#Assignment operators:
a = 10
print('a is:', a)
a += 10
print('a is:', a)
a -= 1
print('a is:', a)
a *= 2
print('a is:', a)
a /= 2
print('a is:', a)
a //= 4
print('a is:', a)
a %= 3
print('a is:', a)

#Conversion to specified type:
print('the data type of a is:', type(a))
a = int(a)
print('the new data type of a is:', type(a))
a = str(a)
print('the new data type of a is:', type(a))

# %% [markdown]
# <h3> Functions </h3>
#
# Functions can be defined in Python in order to create modular code. The structure of a simple function looks like this:
#
# ```python
# def function_name(argument_1, argument_2, ...):
#     do operations
#     return (result)
# ```
#
# If an argument is assigned with a value it will be the default value for that argument and the argument will become
# <br>
# optional. If there is no default value provided, the argument must be given to the function.
#
# Notice the identation inside the function body! In Python the identation levels tell the scope of
# <br>
# code blocks.
#
# Adding a string literal to the beginning of a function is called writing docstring to the function.
# <br>
# The docstrings are displayed when the help() function is called on the function.
#
# Now let's see how to create and use functions in Python

# %%
#Create a function that computes the hypotenuse of a right angled triangle

#Function computing square root
def sqrt(x):
    return(x**(1/2))

# Calculate hypotenuse
def hypotenuse(a, b):
    c = sqrt(a**2+b**2)
    return c

#Using the function:
a = 3
b = 4
c = hypotenuse(a,b)

print('a is', a, 'b is', b, 'computed c is', c)


#Create a threshold function with default threshold value and docstrings
def threshold(x, threshold=0.5):
    '''Threshold function
    
    Returns the input if it is greater than the threshold value
    or returns zero if it is smaller than the threshold value.
    
    Inputs:
        x (float) - input value to be thresholded
        threshold (float) - threshold value (0.5 is default)
    
    Returns:
        (float) - thresholded value
    '''
    return(threshold*x//threshold)
    
print('Threshold 3 with default threshold value: ', threshold(3))
print('Threshold 0.2 with default threshold value: ', threshold(0.2))
print('Threshold 2.7 with threshold value 1.4: ', threshold(2.7, threshold=1.4))

help(threshold)

# %% [markdown]
# <h2>Excersise 1.1</h2>
#
# Create a function that takes in three float numbers as arguments.
# <br>
# These numbers will represent the coefficients $(a,b,c)$ of a second order equation like:
#
# $$ax^2+bx+c=0$$
#
# The function should solve the equation for $x$ and return the results (use multiple values with the return).
# <br>
# The function should also have a docstring describing what the function does.

# %% [markdown]
# See solution here: [Excersise 1.1 solution](Excersise_1_1.ipynb)
#
# Continue: [1.2 Conditions and Loops](Conditions_Loops.ipynb)
